# %% [markdown]
# ## Part 1. Finance-datareader 활용.
#
# 코스피 지수와 코스피 구성종목 중 가장 비중 높은 4개 기업 데이터 불러오기¶
# .

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %%
# !pip install Finance-datareader
# Out:
# Requirement already satisfied: Finance-datareader in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (0.9.33)
# Requirement already satisfied: requests>=2.3.0 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from Finance-datareader) (2.28.0)
# Requirement already satisfied: pandas>=0.19.2 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from Finance-datareader) (1.4.2)
# Requirement already satisfied: requests-file in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from Finance-datareader) (1.5.1)
# Requirement already satisfied: tqdm in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from Finance-datareader) (4.64.0)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from Finance-datareader) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from pandas>=0.19.2->Finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from pandas>=0.19.2->Finance-datareader) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from pandas>=0.19.2->Finance-datareader) (1.22.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from requests>=2.3.0->Finance-datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from requests>=2.3.0->Finance-datareader) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from requests>=2.3.0->Finance-datareader) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from requests>=2.3.0->Finance-datareader) (2022.5.18.1)
# Requirement already satisfied: six in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from requests-file->Finance-datareader) (1.15.0)
# Requirement already satisfied: colorama in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from tqdm->Finance-datareader) (0.4.4)

# %%
import FinanceDataReader as fdr

# %%
# 코스피 상장 기업 데이터 불러오기
df_kospi = fdr.StockListing('KOSPI')
df_kospi.head(10)
# Out:
#     Symbol Market                Name           Sector             Industry  \
# 1   095570  KOSPI              AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)
# 2   006840  KOSPI               AK홀딩스           기타 금융업                 지주사업
# 6   152100  KOSPI         ARIRANG 200              NaN                  NaN
# 7   295820  KOSPI     ARIRANG 200동일가중              NaN                  NaN
# 8   253150  KOSPI   ARIRANG 200선물레버리지              NaN                  NaN
# 9   253160  KOSPI  ARIRANG 200선물인버스2X              NaN                  NaN
# 10  395750  KOSPI   ARIRANG ESG가치주액티브              NaN                  NaN
# 11  395760  KOSPI   ARIRANG ESG성장주액티브              NaN                  NaN
# 12  278420  KOSPI     ARIRANG ESG우수기업              NaN                  NaN
# 13  429740  KOSPI      ARIRANG Fn K리츠              NaN                  NaN
#
#    ListingDate SettleMonth     Representative                       HomePage  \
# 1   2015-08-21         12월           박대현, 손삼달         http://www.ajnet.co.kr
# 2   1999-08-11         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr
# 6          NaT         NaN                NaN                            NaN
# 7          NaT         NaN                NaN                            NaN
# 8          NaT         NaN                NaN                            NaN
# 9          NaT         NaN                NaN                            NaN
# 10         NaT         NaN                NaN                            NaN
# 11         NaT         NaN                NaN                            NaN
# 12         NaT         NaN                NaN                            NaN
# 13         NaT         NaN                NaN                            NaN
#
#    Region
# 1   서울특별시
# 2   서울특별시
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN

# %%
df_kospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5647 entries, 1 to 7341
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          5647 non-null   object
#  1   Market          5647 non-null   object
#  2   Name            5647 non-null   object
#  3   Sector          821 non-null    object
#  4   Industry        810 non-null    object
#  5   ListingDate     821 non-null    datetime64[ns]
#  6   SettleMonth     821 non-null    object
#  7   Representative  821 non-null    object
#  8   HomePage        791 non-null    object
#  9   Region          821 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 485.3+ KB

# %%
# 삼성전자, 엔솔, 하이닉스 Symbol 구하기
cond1 = df_kospi["Name"] == "삼성전자"
cond2 = df_kospi["Name"] == "LG에너지솔루션"
cond3 = df_kospi["Name"] == "SK하이닉스"
cond4 = df_kospi["Name"] == "삼성바이오로직스"
df_kospi[cond1 | cond2 | cond3 | cond4]
# Symbol - 삼성전자: 005930, LG에너지솔루션: 373220, SK하이닉스: 000660, 삼성바이오로직스: 207940
# Out:
#       Symbol Market      Name                 Sector  \
# 1615  373220  KOSPI  LG에너지솔루션         일차전지 및 축전지 제조업
# 1754  000660  KOSPI    SK하이닉스                반도체 제조업
# 3887  207940  KOSPI  삼성바이오로직스  기초 의약물질 및 생물학적 제제 제조업
# 3894  005930  KOSPI      삼성전자         통신 및 방송 장비 제조업
#
#                                                Industry ListingDate  \
# 1615                                2차전지 (소형,ESS,자동차전지)  2022-01-27
# 1754                                 반도체,컴퓨터,통신기기 제조,도매  1996-12-26
# 3887                                             바이오의약품  2016-11-10
# 3894  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11
#
#      SettleMonth           Representative                         HomePage  \
# 1615         12월                      권영수                              NaN
# 1754         12월          박정호, 곽노정 (각자대표)           http://www.skhynix.com
# 3887         12월  임존종보 (Rim John Chongbo)  http://www.samsungbiologics.com
# 3894         12월                 한종희, 경계현             http://www.sec.co.kr
#
#      Region
# 1615  서울특별시
# 1754    경기도
# 3887  인천광역시
# 3894    경기도

# %%
df = pd.DataFrame(columns=["Close", "Open", "High", "Low", "Volume", "Change"])

# KOSPI지수, 삼성전자, 엔솔, 하이닉스의 시계열 데이터 df 데이터프레임에 추가하기
symbols = ["KS11", "005930", "373220", "000660"]
names = ["KOSPI200", "Samsung Electronics", "LGensol", "SKhynix"]
for symbol, name in zip(symbols, names):
  dataset = fdr.DataReader(symbol, '2015-01-01')
  dataset["Name"] = name
  df = df.append(dataset)

df.head()
# Out:
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\2819040439.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dataset)
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\2819040439.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dataset)
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\2819040439.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dataset)
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\2819040439.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dataset)
#               Close     Open     High      Low       Volume  Change      Name
# 2015-01-02  1926.44  1914.24  1929.15  1909.67  258780000.0  0.0057  KOSPI200
# 2015-01-05  1915.75  1921.96  1921.96  1903.37  313440000.0 -0.0055  KOSPI200
# 2015-01-06  1882.45  1895.48  1900.02  1877.38  303690000.0 -0.0174  KOSPI200
# 2015-01-07  1883.83   1878.9   1887.6  1876.27  280510000.0  0.0007  KOSPI200
# 2015-01-08  1904.65  1895.85  1907.23  1891.77  262210000.0  0.0111  KOSPI200

# %%
df.describe()
# Out:
#           Close     Open     High      Low        Volume  Change      Name
# count    5583.0   5583.0   5583.0   5583.0  5.583000e+03  5582.0      5583
# unique   3227.0   3232.0   3255.0   3244.0  5.428000e+03  3635.0         4
# top     82900.0  47000.0  82500.0  82000.0  1.020000e+09     0.0  KOSPI200
# freq       15.0     16.0     14.0     17.0  8.000000e+00   166.0      1831

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5583 entries, 2015-01-02 to 2022-06-13
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   5583 non-null   object
#  1   Open    5583 non-null   object
#  2   High    5583 non-null   object
#  3   Low     5583 non-null   object
#  4   Volume  5583 non-null   object
#  5   Change  5582 non-null   object
#  6   Name    5583 non-null   object
# dtypes: object(7)
# memory usage: 348.9+ KB

# %%
# KOSPI지수를 비롯한 각 주식의 종가 데이터 그래프로 그리기
plt.figure(figsize=(15, 6))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, name in enumerate(names):
  plt.subplot(2, 2, i+1)
  each_df = df[df.Name == name]
  each_df["Close"].plot()
  plt.ylabel('Close')
  plt.xlabel(None)
  plt.title(f"Closing Price of {name}")

plt.tight_layout()

# %%
# KOSPI지수를 비롯한 각 주식의 Volume 데이터 그래프로 그리기
plt.figure(figsize=(15, 7))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, name in enumerate(names):
    plt.subplot(2, 2, i+1)
    each_df = df[df.Name == name]
    each_df['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {name}")
    
plt.tight_layout()

# %% [markdown]
# ### Part 2. KOSPI지수와 각 주식들의 10일, 20일, 50일 이동평균 구하기

# %%
ma_day = [10, 20, 50]


# df에 이동평균 컬럼 추가
tmp_df = pd.DataFrame(columns=["Close", "Open", "High", "Low", "Volume", "Change", "Name"])
for name in names:
    each_df = df[df.Name == name]
    tmp_df = pd.concat([tmp_df,each_df], axis=0)

    each_closing_price = each_df.loc[:, "Close"]
    for ma in ma_day:
        added_column_name = f"MA for {ma} days"
        tmp_df[added_column_name] = each_closing_price.rolling(ma).mean() # rolling: 이동평균 구하는 메서드

df = tmp_df

# %%
df.head(10)
# Out:
#               Close     Open     High      Low       Volume  Change      Name  \
# 2015-01-02  1926.44  1914.24  1929.15  1909.67  258780000.0  0.0057  KOSPI200
# 2015-01-05  1915.75  1921.96  1921.96  1903.37  313440000.0 -0.0055  KOSPI200
# 2015-01-06  1882.45  1895.48  1900.02  1877.38  303690000.0 -0.0174  KOSPI200
# 2015-01-07  1883.83   1878.9   1887.6  1876.27  280510000.0  0.0007  KOSPI200
# 2015-01-08  1904.65  1895.85  1907.23  1891.77  262210000.0  0.0111  KOSPI200
# 2015-01-09   1924.7   1919.8   1929.1  1915.85  308780000.0  0.0105  KOSPI200
# 2015-01-12  1920.95  1918.18  1924.66  1917.88  311920000.0 -0.0019  KOSPI200
# 2015-01-13  1917.14  1915.03  1920.77  1910.27  338990000.0  -0.002  KOSPI200
# 2015-01-14  1913.66  1919.31  1925.68  1913.51  297520000.0 -0.0018  KOSPI200
# 2015-01-15  1914.14  1914.06  1919.69   1908.6  266540000.0  0.0003  KOSPI200
#
#             MA for 10 days  MA for 20 days  MA for 50 days
# 2015-01-02             NaN             NaN             NaN
# 2015-01-05             NaN             NaN             NaN
# 2015-01-06             NaN             NaN             NaN
# 2015-01-07             NaN             NaN             NaN
# 2015-01-08             NaN             NaN             NaN
# 2015-01-09             NaN             NaN             NaN
# 2015-01-12             NaN             NaN             NaN
# 2015-01-13             NaN             NaN             NaN
# 2015-01-14             NaN             NaN             NaN
# 2015-01-15         48765.0             NaN             NaN

# %%
df.tail(10)
# Out:
#              Close    Open    High     Low   Volume    Change     Name  \
# 2022-05-27  106000  105500  107000  105000  3686487  0.029126  SKhynix
# 2022-05-30  107000  108000  108000  106000  2054526  0.009434  SKhynix
# 2022-05-31  108000  106500  108000  105500  4024509  0.009346  SKhynix
# 2022-06-02  107000  106000  107500  106000  3097583 -0.009259  SKhynix
# 2022-06-03  107000  108000  108500  107000  1638006       0.0  SKhynix
# 2022-06-07  104000  105500  106000  103500  3174521 -0.028037  SKhynix
# 2022-06-08  106000  104500  107500  104500  3075530  0.019231  SKhynix
# 2022-06-09  105500  105500  107000  104500  4640744 -0.004717  SKhynix
# 2022-06-10  103500  104000  104500  102500  3480289 -0.018957  SKhynix
# 2022-06-13   99000  100000  101000   99000  4090658 -0.043478  SKhynix
#
#             MA for 10 days  MA for 20 days  MA for 50 days
# 2022-05-27        109850.0        109900.0        112850.0
# 2022-05-30        109500.0        109625.0        112510.0
# 2022-05-31        109050.0        109500.0        112230.0
# 2022-06-02        108400.0        109350.0        111900.0
# 2022-06-03        108000.0        109225.0        111570.0
# 2022-06-07        107150.0        109050.0        111240.0
# 2022-06-08        106450.0        108975.0        111000.0
# 2022-06-09        106150.0        108750.0        110750.0
# 2022-06-10        105700.0        108400.0        110420.0
# 2022-06-13        105300.0        107900.0        109980.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5583 entries, 2015-01-02 to 2022-06-13
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Close           5583 non-null   object
#  1   Open            5583 non-null   object
#  2   High            5583 non-null   object
#  3   Low             5583 non-null   object
#  4   Volume          5583 non-null   object
#  5   Change          5582 non-null   object
#  6   Name            5583 non-null   object
#  7   MA for 10 days  5556 non-null   float64
#  8   MA for 20 days  5526 non-null   float64
#  9   MA for 50 days  5436 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 479.8+ KB

# %%
# 이동평균 컬럼에 대한 그래프 보여주기

fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

kospi = df[df.Name == "KOSPI200"]
samsung = df[df.Name == "Samsung Electronics"]
lg = df[df.Name == "LGensol"]
sk = df[df.Name == "SKhynix"]

kospi[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('KOSPI200')

samsung[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('Samsung Electronics')

lg[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('LGensol')

sk[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('SK Biologics')
# Out:
# Text(0.5, 1.0, 'SK Biologics')

# %% [markdown]
# ## Part 3. 지수와 주식의 daily 변화량 구하기

# %%
tmp_df = pd.DataFrame(columns=df.columns)
for name in names:
    each_df = df[df.Name == name]
    tmp_df = tmp_df.append(each_df)
    tmp_df["Daily Return"] = each_df.Close.pct_change() # pct_change: 로우간 변화율 구하는 메서드
df = tmp_df
# Out:
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3873642507.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(each_df)
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3873642507.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(each_df)
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3873642507.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(each_df)
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3873642507.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(each_df)

# %%
df.head(10)
# Out:
#               Close     Open     High      Low       Volume  Change      Name  \
# 2015-01-02  1926.44  1914.24  1929.15  1909.67  258780000.0  0.0057  KOSPI200
# 2015-01-05  1915.75  1921.96  1921.96  1903.37  313440000.0 -0.0055  KOSPI200
# 2015-01-06  1882.45  1895.48  1900.02  1877.38  303690000.0 -0.0174  KOSPI200
# 2015-01-07  1883.83   1878.9   1887.6  1876.27  280510000.0  0.0007  KOSPI200
# 2015-01-08  1904.65  1895.85  1907.23  1891.77  262210000.0  0.0111  KOSPI200
# 2015-01-09   1924.7   1919.8   1929.1  1915.85  308780000.0  0.0105  KOSPI200
# 2015-01-12  1920.95  1918.18  1924.66  1917.88  311920000.0 -0.0019  KOSPI200
# 2015-01-13  1917.14  1915.03  1920.77  1910.27  338990000.0  -0.002  KOSPI200
# 2015-01-14  1913.66  1919.31  1925.68  1913.51  297520000.0 -0.0018  KOSPI200
# 2015-01-15  1914.14  1914.06  1919.69   1908.6  266540000.0  0.0003  KOSPI200
#
#            MA for 10 days MA for 20 days MA for 50 days  Daily Return
# 2015-01-02            NaN            NaN            NaN           NaN
# 2015-01-05            NaN            NaN            NaN     -0.002094
# 2015-01-06            NaN            NaN            NaN     -0.003148
# 2015-01-07            NaN            NaN            NaN     -0.002105
# 2015-01-08            NaN            NaN            NaN      0.053797
# 2015-01-09            NaN            NaN            NaN     -0.005005
# 2015-01-12            NaN            NaN            NaN      0.012072
# 2015-01-13            NaN            NaN            NaN     -0.025845
# 2015-01-14            NaN            NaN            NaN     -0.002041
# 2015-01-15        48765.0            NaN            NaN      0.012270

# %%
# daily return percentage 시각화하기
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)


kospi = df[df.Name == "KOSPI200"]
samsung = df[df.Name == "Samsung Electronics"]
lg = df[df.Name == "LGensol"]
sk = df[df.Name == "SKhynix"]

kospi['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('KOSPI200')

samsung['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('Samsung Electronics')

lg['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('LGensol')

sk['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('SK Biologics')

fig.tight_layout()

# %%
plt.figure(figsize=(12, 7))
print(names)
for i, name in enumerate(names):
    plt.subplot(2, 2, i+1)
    each_df = df[df.Name == name]
    each_df['Daily Return'].hist(bins=50)
    plt.ylabel('Daily Return')
    plt.title(f'{name}')
  
plt.tight_layout()
# Out:
# ['KOSPI200', 'Samsung Electronics', 'LGensol', 'SKhynix']

# %% [markdown]
# ## Part 4. KOSPI지수와 각 주식들의 종가 들의 상관관계 파악하기¶
#
# --> KOSPI 구성종목들 중 가장 비중이 큰 삼성전자와 KOSPI 지수와의 상관계수가 가장 크다는 점을 확인하고 싶었음

# %%
# Grab all the closing prices for the stock list into one DataFrame
symbols = ["KS11", "005930", "373220", "000660"]
names = ["KOSPI200", "Samsung Electronics", "LGensol", "SKhynix"]

df_list = [fdr.DataReader(symbol, '2015-01-01')['Close'] for symbol, name in zip(symbols, names)]

# %%
closing_df = pd.concat(df_list, axis=1)
closing_df.columns = [name for name in names]
closing_df.head()
# Out:
#             KOSPI200  Samsung Electronics  LGensol  SKhynix
# Date
# 2015-01-02   1926.44                26600      NaN    47750
# 2015-01-05   1915.75                26660      NaN    47650
# 2015-01-06   1882.45                25900      NaN    47500
# 2015-01-07   1883.83                26140      NaN    47400
# 2015-01-08   1904.65                26280      NaN    49950

# %%
daily_ret_rate = closing_df.pct_change()
daily_ret_rate.head()
# Out:
#             KOSPI200  Samsung Electronics  LGensol   SKhynix
# Date
# 2015-01-02       NaN                  NaN      NaN       NaN
# 2015-01-05 -0.005549             0.002256      NaN -0.002094
# 2015-01-06 -0.017382            -0.028507      NaN -0.003148
# 2015-01-07  0.000733             0.009266      NaN -0.002105
# 2015-01-08  0.011052             0.005356      NaN  0.053797

# %%
sns.jointplot(x='KOSPI200', y='KOSPI200', data=daily_ret_rate, kind='scatter', color='seagreen')

# %%
sns.jointplot(x='KOSPI200', y='Samsung Electronics', data=daily_ret_rate, kind='scatter')

# %%
sns.pairplot(daily_ret_rate, kind='reg')

# %%
# Set up our figure by naming it daily_ret_rate_fig, call PairPLot on the DataFrame
daily_ret_rate_fig = sns.PairGrid(daily_ret_rate.dropna())

# Using map_upper we can specify what the upper triangle will look like.
daily_ret_rate_fig.map_upper(plt.scatter, color='purple')

# We can also define the lower triangle in the figure, inclufing the plot type (kde) 
# or the color map (BluePurple)
daily_ret_rate_fig.map_lower(sns.kdeplot, cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the daily daily_ret_rate
daily_ret_rate_fig.map_diag(plt.hist, bins=30)

# %%
# Set up our figure by naming it closing_fig, call PairPLot on the DataFrame
closing_fig = sns.PairGrid(closing_df)

# Using map_upper we can specify what the upper triangle will look like.
closing_fig.map_upper(plt.scatter,color='purple')

# We can also define the lower triangle in the figure, inclufing the plot type (kde) or the color map (BluePurple)
closing_fig.map_lower(sns.kdeplot,cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the daily return
closing_fig.map_diag(plt.hist,bins=30)

# %%
# daily 수익률 기준으로 확인한 상관관계 매트릭스
sns.heatmap(daily_ret_rate.corr(), annot=True, cmap='summer')
# Out:
# <AxesSubplot:>

# %%
# 종가 기준으로 확인한 상관관계 매트릭스
sns.heatmap(closing_df.corr(), annot=True, cmap='summer')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Part 5. LSTM 모델을 통해 삼성전자 종가, KOSPI 지수 예측
#
# - 종가를 기준으로 LSTM 모델을 활용해 삼성전자 '종가' 자체를 예측!! 상승, 답보, 하락 예측이 아님
# - MinMaxScaler 사용해서 Scaling 전처리
# - Cross-validation 과정이 추가되어도 좋을 듯
# - 한계점
#     1. 감성지표를 활용하기 전 모델 적용이라 하더라도 피쳐 사용이 너무 없다.
#         - 이동평균이나 지수평활법 같이 금융데이터 시계열 분석에서 활용하는 피쳐들이 있다고 하기는 하는데 추가적으로 찾아봐야 할 듯
#         - 시계열 데이터셋이기 때문에 재무제표 내용을 피쳐로 추가하기에는 어려움이 있어 보임
#     2. 가격 자체가 결과값으로 나오기 때문에 Precision, Recall, F score를 어떻게 도출해야 할 지 모르겠다<br>
#     개인적으로 Confusion Matrix를 마지막에 보여주고 싶음

# %% [markdown]
# ## 1. 독립변수 개념 정리
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
#
# ![image.png](data:image/png;base64,...)
#
# <br>
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %%
# !pip install Finance-datareader
# !pip install ta
# Out:
# Requirement already satisfied: Finance-datareader in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (0.9.33)
# Requirement already satisfied: requests>=2.3.0 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from Finance-datareader) (2.28.0)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from Finance-datareader) (4.9.0)
# Requirement already satisfied: requests-file in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from Finance-datareader) (1.5.1)
# Requirement already satisfied: tqdm in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from Finance-datareader) (4.64.0)
# Requirement already satisfied: pandas>=0.19.2 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from Finance-datareader) (1.4.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from pandas>=0.19.2->Finance-datareader) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from pandas>=0.19.2->Finance-datareader) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from pandas>=0.19.2->Finance-datareader) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from requests>=2.3.0->Finance-datareader) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from requests>=2.3.0->Finance-datareader) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from requests>=2.3.0->Finance-datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from requests>=2.3.0->Finance-datareader) (3.3)
# Requirement already satisfied: six in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from requests-file->Finance-datareader) (1.15.0)
# Requirement already satisfied: colorama in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from tqdm->Finance-datareader) (0.4.4)
# Requirement already satisfied: ta in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from ta) (1.4.2)
# Requirement already satisfied: numpy in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from ta) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\kr_finbert\lib\site-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\prizejune\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.8.1->pandas->ta) (1.15.0)

# %%
import ta
import FinanceDataReader as fdr

# %%
# s: 삼성전자에 대한 데이터프레임
s = fdr.DataReader('323410', '2017-06-01')
s.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-08-06  53700  69800  51000  69800  59402373       NaN
# 2021-08-09  69800  89100  69000  78500  44833696  0.124642
# 2021-08-10  81800  85600  68000  71400  26495122 -0.090446
# 2021-08-11  71200  77500  68100  74400  21592734  0.042017
# 2021-08-12  73600  75400  72700  73800   5878196 -0.008065

# %%
s.insert(6, "Rn", s.Close / s.Close.shift(1))
s.head()
# Out:
#              Open   High    Low  Close    Volume    Change        Rn
# Date
# 2021-08-06  53700  69800  51000  69800  59402373       NaN       NaN
# 2021-08-09  69800  89100  69000  78500  44833696  0.124642  1.124642
# 2021-08-10  81800  85600  68000  71400  26495122 -0.090446  0.909554
# 2021-08-11  71200  77500  68100  74400  21592734  0.042017  1.042017
# 2021-08-12  73600  75400  72700  73800   5878196 -0.008065  0.991935

# %%
s["MRn"] = s.Rn.rolling(3).mean()
s.head(10)
# Out:
#              Open   High    Low  Close    Volume    Change        Rn       MRn
# Date
# 2021-08-06  53700  69800  51000  69800  59402373       NaN       NaN       NaN
# 2021-08-09  69800  89100  69000  78500  44833696  0.124642  1.124642       NaN
# 2021-08-10  81800  85600  68000  71400  26495122 -0.090446  0.909554       NaN
# 2021-08-11  71200  77500  68100  74400  21592734  0.042017  1.042017  1.025404
# 2021-08-12  73600  75400  72700  73800   5878196 -0.008065  0.991935  0.981169
# 2021-08-13  73500  78600  73500  76600  10907993  0.037940  1.037940  1.023964
# 2021-08-17  78100  88300  77500  87400  24272931  0.140992  1.140992  1.056956
# 2021-08-18  89600  94400  83800  84500  21008684 -0.033181  0.966819  1.048584
# 2021-08-19  87300  92300  86400  92000  13606690  0.088757  1.088757  1.065523
# 2021-08-20  92800  94000  88600  91000  15815275 -0.010870  0.989130  1.014902

# %%
def get_volatility(rn, mrn, vol_day):
    l = len(rn)
    result = [np.nan for _ in range(l)]
    for i in range(l - 1, -1, -1):
        std = 0
        tmp_list = rn[i+1-vol_day:i+1]
        # print(tmp_list)
        for v in tmp_list:
            std += (v - mrn[i]) ** 2
        std = std ** (1/2)
        result[i] = std
    return result

rn = np.log(s.Close / s.Close.shift(1))
# print(get_volatility([1, 2, 3, 4, 5], [np.nan, np.nan, 2, 3, 4], 3))
for vol_day in [10,30,60,80,120,180,360]:
    rn_series = pd.Series(rn)
    mrn = rn_series.rolling(vol_day).mean()
    volatility = get_volatility(rn, mrn, vol_day)
    added_column = f'Volatility{vol_day}'
    s[added_column] = volatility

# %%
s.tail()
# Out:
#              Open   High    Low  Close   Volume    Change        Rn       MRn  \
# Date
# 2022-06-07  41100  41900  40700  41500  1678530  0.008505  1.008505  1.007149
# 2022-06-08  41500  41500  39600  40400  2070212 -0.026506  0.973494  1.004874
# 2022-06-09  40200  42300  39950  41050  6994591  0.016089  1.016089  0.999363
# 2022-06-10  40700  40750  39100  39150  3297078 -0.046285  0.953715  0.981099
# 2022-06-13  38300  38350  36000  36000  3642865 -0.080460  0.919540  0.963115
#
#             Volatility10  Volatility30  Volatility60  Volatility80  \
# Date
# 2022-06-07      0.050586      0.119790      0.166315      0.200545
# 2022-06-08      0.058430      0.118456      0.167044      0.201998
# 2022-06-09      0.057289      0.117168      0.166767      0.200253
# 2022-06-10      0.072643      0.123824      0.162656      0.205101
# 2022-06-13      0.103671      0.145938      0.180355      0.216620
#
#             Volatility120  Volatility180  Volatility360
# Date
# 2022-06-07       0.260813       0.364087            NaN
# 2022-06-08       0.257714       0.364857            NaN
# 2022-06-09       0.258317       0.363048            NaN
# 2022-06-10       0.261937       0.360546            NaN
# 2022-06-13       0.273741       0.360866            NaN

# %%
ma_day = [3,10,20,60,120,180,360]
for ma in ma_day:
    added_column_name = f"MA{ma}"
    s[added_column_name] = s.Close.rolling(ma).mean() # rolling: 이동평균 구하는 메서드

# %%
s.head()
# Out:
#              Open   High    Low  Close    Volume    Change        Rn  \
# Date
# 2021-08-06  53700  69800  51000  69800  59402373       NaN       NaN
# 2021-08-09  69800  89100  69000  78500  44833696  0.124642  1.124642
# 2021-08-10  81800  85600  68000  71400  26495122 -0.090446  0.909554
# 2021-08-11  71200  77500  68100  74400  21592734  0.042017  1.042017
# 2021-08-12  73600  75400  72700  73800   5878196 -0.008065  0.991935
#
#                  MRn  Volatility10  Volatility30  ...  Volatility120  \
# Date                                              ...
# 2021-08-06       NaN           0.0           0.0  ...            0.0
# 2021-08-09       NaN           0.0           0.0  ...            0.0
# 2021-08-10       NaN           0.0           0.0  ...            0.0
# 2021-08-11  1.025404           0.0           0.0  ...            0.0
# 2021-08-12  0.981169           0.0           0.0  ...            0.0
#
#             Volatility180  Volatility360           MA3  MA10  MA20  MA60  \
# Date
# 2021-08-06            0.0            NaN           NaN   NaN   NaN   NaN
# 2021-08-09            0.0            NaN           NaN   NaN   NaN   NaN
# 2021-08-10            0.0            NaN  73233.333333   NaN   NaN   NaN
# 2021-08-11            0.0            NaN  74766.666667   NaN   NaN   NaN
# 2021-08-12            0.0            NaN  73200.000000   NaN   NaN   NaN
#
#             MA120  MA180  MA360
# Date
# 2021-08-06    NaN    NaN    NaN
# 2021-08-09    NaN    NaN    NaN
# 2021-08-10    NaN    NaN    NaN
# 2021-08-11    NaN    NaN    NaN
# 2021-08-12    NaN    NaN    NaN
#
# [5 rows x 22 columns]

# %%
# ATR 객체 만들고 시리즈 생성
ATR = ta.volatility.AverageTrueRange(high=s.High, low=s.Low, close=s.Close, window=14)
atr = ATR.average_true_range()

# %%
# MACD 객체 만들고 관련 시리즈 모두 생성 - 어떤 시리즈를 열에 추가할지는 정해야 함
MACD = ta.trend.MACD(close=s.Close)
macd_line = MACD.macd()
macd_hist = MACD.macd_diff()
macd_sign = MACD.macd_signal()

# %%
# PSAR 객체 만들고 관련 시리즈 모두 생성 - 어떤 시리즈를 열에 추가할지는 정해야 함  
PSAR = ta.trend.PSARIndicator(s.High, s.Low, s.Close)
psar = PSAR.psar()
psar_down = PSAR.psar_down()
psar_down_indicator = PSAR.psar_down_indicator()
psar_up = PSAR.psar_up()
psar_up_indicator = PSAR.psar_up_indicator()
# Out:
# C:\ProgramData\Anaconda3\envs\kr_finbert\lib\site-packages\ta\trend.py:938: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_up = pd.Series(index=self._psar.index)
# C:\ProgramData\Anaconda3\envs\kr_finbert\lib\site-packages\ta\trend.py:939: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_down = pd.Series(index=self._psar.index)

# %%
# RSI(Relative Strength Index) 시리즈 생성
rsi = ta.momentum.rsi(s.Close)

# %%
# ADX(Average Directional Movement Index) 시리즈 생성
adx = ta.trend.adx(s.High, s.Low, s.Close)
# Out:
# C:\ProgramData\Anaconda3\envs\kr_finbert\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\ProgramData\Anaconda3\envs\kr_finbert\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)

# %%
# OBV(On-balance volume) 시리즈 생성
obv = ta.volume.on_balance_volume(s.Close, s.Volume)

# %%
# Oscillator 시리즈 생성
oscillator = ta.momentum.awesome_oscillator(s.High, s.Low)

# %%
# 지금까지 생성한 시리즈 컬럼에 추가
s["ATR"] = atr
s["MACD-line"] = macd_line
s["MACD-hist"] = macd_hist
s["MACD-sign"] = macd_sign
s["PSAR"] = psar
s["PSAR-down"] = psar_down
s["PSAR-up"] = psar_up
s["RSI"] = rsi
s["ADX"] = adx
s["OBV"] = obv
s["OSCILLATOR"] = oscillator

# %%
s.head()
# Out:
#              Open   High    Low  Close    Volume    Change        Rn  \
# Date
# 2021-08-06  53700  69800  51000  69800  59402373       NaN       NaN
# 2021-08-09  69800  89100  69000  78500  44833696  0.124642  1.124642
# 2021-08-10  81800  85600  68000  71400  26495122 -0.090446  0.909554
# 2021-08-11  71200  77500  68100  74400  21592734  0.042017  1.042017
# 2021-08-12  73600  75400  72700  73800   5878196 -0.008065  0.991935
#
#                  MRn  Volatility10  Volatility30  ...  MACD-line  MACD-hist  \
# Date                                              ...
# 2021-08-06       NaN           0.0           0.0  ...        NaN        NaN
# 2021-08-09       NaN           0.0           0.0  ...        NaN        NaN
# 2021-08-10       NaN           0.0           0.0  ...        NaN        NaN
# 2021-08-11  1.025404           0.0           0.0  ...        NaN        NaN
# 2021-08-12  0.981169           0.0           0.0  ...        NaN        NaN
#
#             MACD-sign     PSAR  PSAR-down  PSAR-up  RSI  ADX        OBV  \
# Date
# 2021-08-06        NaN  69800.0        NaN      NaN  NaN  0.0   59402373
# 2021-08-09        NaN  78500.0        NaN      NaN  NaN  0.0  104236069
# 2021-08-10        NaN  69800.0    69800.0      NaN  NaN  0.0   77740947
# 2021-08-11        NaN  68000.0        NaN  68000.0  NaN  0.0   99333681
# 2021-08-12        NaN  68000.0        NaN  68000.0  NaN  0.0   93455485
#
#             OSCILLATOR
# Date
# 2021-08-06         NaN
# 2021-08-09         NaN
# 2021-08-10         NaN
# 2021-08-11         NaN
# 2021-08-12         NaN
#
# [5 rows x 33 columns]

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 207 entries, 2021-08-06 to 2022-06-13
# Data columns (total 33 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Open           207 non-null    int64
#  1   High           207 non-null    int64
#  2   Low            207 non-null    int64
#  3   Close          207 non-null    int64
#  4   Volume         207 non-null    int64
#  5   Change         206 non-null    float64
#  6   Rn             206 non-null    float64
#  7   MRn            204 non-null    float64
#  8   Volatility10   206 non-null    float64
#  9   Volatility30   206 non-null    float64
#  10  Volatility60   206 non-null    float64
#  11  Volatility80   206 non-null    float64
#  12  Volatility120  206 non-null    float64
#  13  Volatility180  206 non-null    float64
#  14  Volatility360  0 non-null      float64
#  15  MA3            205 non-null    float64
#  16  MA10           198 non-null    float64
#  17  MA20           188 non-null    float64
#  18  MA60           148 non-null    float64
#  19  MA120          88 non-null     float64
#  20  MA180          28 non-null     float64
#  21  MA360          0 non-null      float64
#  22  ATR            207 non-null    float64
#  23  MACD-line      182 non-null    float64
#  24  MACD-hist      174 non-null    float64
#  25  MACD-sign      174 non-null    float64
#  26  PSAR           207 non-null    float64
#  27  PSAR-down      122 non-null    float64
#  28  PSAR-up        83 non-null     float64
#  29  RSI            194 non-null    float64
#  30  ADX            207 non-null    float64
#  31  OBV            207 non-null    int64
#  32  OSCILLATOR     174 non-null    float64
# dtypes: float64(27), int64(6)
# memory usage: 55.0 KB

# %%
from datetime import datetime

s["negative"] = 0.0
s["neutral"] = 0.0
s["positive"] = 0.0
s["sentiment"] = "null"

filename = "./datasets/kakaobank/kakaobank_cleaned_combined_dataset_finBERT.xlsx"
Fb_dataset = pd.read_excel(filename)
Fb_dataset["date"] = pd.to_datetime(Fb_dataset["date"], format='%Y%m%d')

for i in range(len(s)) : 
    for j in range(len(Fb_dataset)) :
        if(s.index[i] == Fb_dataset['date'][j]) :
            s["negative"][i] = Fb_dataset['negative'][j]
            s["neutral"][i] = Fb_dataset['neutral'][j]
            s["positive"][i] = Fb_dataset['positive'][j]
            s["sentiment"][i] = Fb_dataset['sentiment_to_num'][j]

s
# Out:
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3604424943.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s["negative"][i] = Fb_dataset['negative'][j]
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3604424943.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s["neutral"][i] = Fb_dataset['neutral'][j]
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3604424943.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s["positive"][i] = Fb_dataset['positive'][j]
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3604424943.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s["sentiment"][i] = Fb_dataset['sentiment_to_num'][j]
#              Open   High    Low  Close    Volume    Change        Rn  \
# Date
# 2021-08-06  53700  69800  51000  69800  59402373       NaN       NaN
# 2021-08-09  69800  89100  69000  78500  44833696  0.124642  1.124642
# 2021-08-10  81800  85600  68000  71400  26495122 -0.090446  0.909554
# 2021-08-11  71200  77500  68100  74400  21592734  0.042017  1.042017
# 2021-08-12  73600  75400  72700  73800   5878196 -0.008065  0.991935
# ...           ...    ...    ...    ...       ...       ...       ...
# 2022-06-07  41100  41900  40700  41500   1678530  0.008505  1.008505
# 2022-06-08  41500  41500  39600  40400   2070212 -0.026506  0.973494
# 2022-06-09  40200  42300  39950  41050   6994591  0.016089  1.016089
# 2022-06-10  40700  40750  39100  39150   3297078 -0.046285  0.953715
# 2022-06-13  38300  38350  36000  36000   3642865 -0.080460  0.919540
#
#                  MRn  Volatility10  Volatility30  ...  PSAR-down  PSAR-up  \
# Date                                              ...
# 2021-08-06       NaN      0.000000      0.000000  ...        NaN      NaN
# 2021-08-09       NaN      0.000000      0.000000  ...        NaN      NaN
# 2021-08-10       NaN      0.000000      0.000000  ...    69800.0      NaN
# 2021-08-11  1.025404      0.000000      0.000000  ...        NaN  68000.0
# 2021-08-12  0.981169      0.000000      0.000000  ...        NaN  68000.0
# ...              ...           ...           ...  ...        ...      ...
# 2022-06-07  1.007149      0.050586      0.119790  ...        NaN  39800.0
# 2022-06-08  1.004874      0.058430      0.118456  ...    41900.0      NaN
# 2022-06-09  0.999363      0.057289      0.117168  ...        NaN  39600.0
# 2022-06-10  0.981099      0.072643      0.123824  ...    42300.0      NaN
# 2022-06-13  0.963115      0.103671      0.145938  ...    42300.0      NaN
#
#                   RSI        ADX        OBV  OSCILLATOR  negative   neutral  \
# Date
# 2021-08-06        NaN   0.000000   59402373         NaN  0.000035  0.000444
# 2021-08-09        NaN   0.000000  104236069         NaN  0.484248  0.510137
# 2021-08-10        NaN   0.000000   77740947         NaN  0.021416  0.971348
# 2021-08-11        NaN   0.000000   99333681         NaN  0.000035  0.999906
# 2021-08-12        NaN   0.000000   93455485         NaN  0.000535  0.977616
# ...               ...        ...        ...         ...       ...       ...
# 2022-06-07  51.412222  23.818792   32733944 -433.529412  0.000393  0.999096
# 2022-06-08  45.872439  22.798673   30663732 -430.735294  0.000041  0.999912
# 2022-06-09  49.345780  21.177625   37658323 -216.029412  0.000034  0.999905
# 2022-06-10  41.053022  20.311738   34361245 -100.735294  0.000083  0.999879
# 2022-06-13  31.578084  21.225007   30718380 -571.764706  0.000000  0.000000
#
#             positive  sentiment
# Date
# 2021-08-06  0.999521          1
# 2021-08-09  0.005615          0
# 2021-08-10  0.007236          0
# 2021-08-11  0.000059          0
# 2021-08-12  0.021849          0
# ...              ...        ...
# 2022-06-07  0.000511          0
# 2022-06-08  0.000047          0
# 2022-06-09  0.000061          0
# 2022-06-10  0.000038          0
# 2022-06-13  0.000000       null
#
# [207 rows x 37 columns]

# %%
s.to_excel("./datasets/kakaobank/kakaobank_stock_dataset_finBERT.xlsx")

# %% [markdown]
# ##### 결측치 채우기

# %%
# 2 = avg(1, 5), 3 = avg(2, 5), 4 = avg(3, 5) 
for i in range(len(s)) : 
    prev_val = {"negVal" : 0.0, "neuVal" : 0.0, "posVal" : 0.0}
    next_val = {"negVal" : 0.0, "neuVal" : 0.0, "posVal" : 0.0}
    avg_val = {"negVal" : 0.0, "neuVal" : 0.0, "posVal" : 0.0}
    if(s['sentiment'][i] == "null") :
        prev_val = {"negVal" : s['negative'][i-1], "neuVal" : s["neutral"][i-1], "posVal" : s["positive"][i-1]}
        for j in range(i, len(s)) :
            if s['sentiment'][j] != "null" :
                next_val = {"negVal" : s['negative'][j], "neuVal" : s["neutral"][j], "posVal" : s["positive"][j]}
                break
        avg_val['negVal'] = (prev_val['negVal']+next_val['negVal'])/2
        avg_val['neuVal'] = (prev_val['neuVal']+next_val['neuVal'])/2
        avg_val['posVal'] = (prev_val['posVal']+next_val['posVal'])/2
        s['negative'][i] = avg_val['negVal']
        s['neutral'][i] = avg_val['neuVal']
        s['positive'][i] = avg_val['posVal']
        s['sentiment'][i] = max(avg_val, key=avg_val.get)
for i in range(len(s)) :
    if(s['sentiment'][i] == "negVal") : s['sentiment'][i] = -1
    elif(s['sentiment'][i] == "neuVal") : s['sentiment'][i] = 0
    elif(s['sentiment'][i] == "posVal") : s['sentiment'][i] = 1
# Out:
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3958940552.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['negative'][i] = avg_val['negVal']
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3958940552.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['neutral'][i] = avg_val['neuVal']
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3958940552.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['positive'][i] = avg_val['posVal']
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3958940552.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['sentiment'][i] = max(avg_val, key=avg_val.get)
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3958940552.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif(s['sentiment'][i] == "neuVal") : s['sentiment'][i] = 0
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3958940552.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if(s['sentiment'][i] == "negVal") : s['sentiment'][i] = -1
# C:\Users\PrizeJune\AppData\Local\Temp\ipykernel_42228\3958940552.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif(s['sentiment'][i] == "posVal") : s['sentiment'][i] = 1

# %%
s
# Out:
#              Open   High    Low  Close    Volume    Change        Rn  \
# Date
# 2021-08-06  53700  69800  51000  69800  59402373       NaN       NaN
# 2021-08-09  69800  89100  69000  78500  44833696  0.124642  1.124642
# 2021-08-10  81800  85600  68000  71400  26495122 -0.090446  0.909554
# 2021-08-11  71200  77500  68100  74400  21592734  0.042017  1.042017
# 2021-08-12  73600  75400  72700  73800   5878196 -0.008065  0.991935
# ...           ...    ...    ...    ...       ...       ...       ...
# 2022-06-07  41100  41900  40700  41500   1678530  0.008505  1.008505
# 2022-06-08  41500  41500  39600  40400   2070212 -0.026506  0.973494
# 2022-06-09  40200  42300  39950  41050   6994591  0.016089  1.016089
# 2022-06-10  40700  40750  39100  39150   3297078 -0.046285  0.953715
# 2022-06-13  38300  38350  36000  36000   3642865 -0.080460  0.919540
#
#                  MRn  Volatility10  Volatility30  ...  PSAR-down  PSAR-up  \
# Date                                              ...
# 2021-08-06       NaN      0.000000      0.000000  ...        NaN      NaN
# 2021-08-09       NaN      0.000000      0.000000  ...        NaN      NaN
# 2021-08-10       NaN      0.000000      0.000000  ...    69800.0      NaN
# 2021-08-11  1.025404      0.000000      0.000000  ...        NaN  68000.0
# 2021-08-12  0.981169      0.000000      0.000000  ...        NaN  68000.0
# ...              ...           ...           ...  ...        ...      ...
# 2022-06-07  1.007149      0.050586      0.119790  ...        NaN  39800.0
# 2022-06-08  1.004874      0.058430      0.118456  ...    41900.0      NaN
# 2022-06-09  0.999363      0.057289      0.117168  ...        NaN  39600.0
# 2022-06-10  0.981099      0.072643      0.123824  ...    42300.0      NaN
# 2022-06-13  0.963115      0.103671      0.145938  ...    42300.0      NaN
#
#                   RSI        ADX        OBV  OSCILLATOR  negative   neutral  \
# Date
# 2021-08-06        NaN   0.000000   59402373         NaN  0.000035  0.000444
# 2021-08-09        NaN   0.000000  104236069         NaN  0.484248  0.510137
# 2021-08-10        NaN   0.000000   77740947         NaN  0.021416  0.971348
# 2021-08-11        NaN   0.000000   99333681         NaN  0.000035  0.999906
# 2021-08-12        NaN   0.000000   93455485         NaN  0.000535  0.977616
# ...               ...        ...        ...         ...       ...       ...
# 2022-06-07  51.412222  23.818792   32733944 -433.529412  0.000393  0.999096
# 2022-06-08  45.872439  22.798673   30663732 -430.735294  0.000041  0.999912
# 2022-06-09  49.345780  21.177625   37658323 -216.029412  0.000034  0.999905
# 2022-06-10  41.053022  20.311738   34361245 -100.735294  0.000083  0.999879
# 2022-06-13  31.578084  21.225007   30718380 -571.764706  0.000041  0.499939
#
#             positive  sentiment
# Date
# 2021-08-06  0.999521          1
# 2021-08-09  0.005615          0
# 2021-08-10  0.007236          0
# 2021-08-11  0.000059          0
# 2021-08-12  0.021849          0
# ...              ...        ...
# 2022-06-07  0.000511          0
# 2022-06-08  0.000047          0
# 2022-06-09  0.000061          0
# 2022-06-10  0.000038          0
# 2022-06-13  0.000019          0
#
# [207 rows x 37 columns]

# %%
s.to_excel("./datasets/kakaobank/kakaobank_stock_dataset_finBERT_notnull.xlsx")
